# %% [markdown]
# # Анализ бизнес-показателей
#
# # Проект "Когортный анализ маркетинговой стратегии компании"

# %% [markdown]
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных-к-анализу" data-toc-modified-id="Подготовка-данных-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных к анализу</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Окупаемость-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Окупаемость рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Общая окупаемость рекламы</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта
#
# Запущено развлекательное приложение Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
#
# **Цель:** проанализировать, почему бизнес по разработке развлекательного приложения Procrastinate Pro+ несёт убытки.
#
# **Задачи:**
#
# 1. Изучить данные
# 2. Проверсти предобработку данных
#     - Анализ пропусков
#     - Поиск артефактов (аномалий)
#     - Проверка типов записи данных
#     - Поиск дубликатов
# 3. Задать функции для расчета и анализа:
#     - LTV
#     - ROI
#     - Удержания пользователей
#     - Конверсии пользователей
# 4. Провести исследовательский анализ данных
#     - Составить профили пользователей
#     - Выяснить, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей
#     - Узнать, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи
#     - Изучить рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей
# 4. Провести маркетинговое исследование
#     - Посчитать общую сумму расходов на маркетинг
#     - Выяснить, как траты распределены по рекламным источникам
#     - Построить визуализацию динамики изменения расходов во времени по каждому источнику
#     - Узнать, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника
# 5. Оценить окупаемость рекламы
#     - Проанализировать окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI
#     - Проверить конверсию и удержание пользователей и динамику изменения этих параметров
#     - Проанализировать окупаемость рекламы с разбивкой по устройствам
#     - Проанализировать окупаемость рекламы с разбивкой по странам
#     - Проанализировать окупаемость рекламы с разбивкой по рекламным каналам
#
# **Описание данных**
#
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
#     User Id — уникальный идентификатор пользователя
#     Device — категория устройства пользователя
#     Session start — дата и время начала сессии
#     Session End — дата и время окончания сессии
#     Channel — идентификатор рекламного источника, из которого пришел пользователь
#     Region - страна пользователя
#
# Таблица orders_log_short (информация о заказах):
#
#     User Id — уникальный id пользователя, который сделал заказ
#     Event Dt — дата и время покупки
#     Revenue — выручка
#
# Таблица costs_short (информация о затратах на маркетинг):
#
#     Channel — идентификатор рекламного источника
#     Dt — дата
#     Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# ## Подготовка данных к анализу

# %% [markdown]
# Загрузим библиотеки

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Загрузим данные

# %%
try:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    orders = pd.read_csv('/datasets/orders_info_short.csv')
    ad_costs = pd.read_csv('/datasets/costs_info_short.csv')  
except: 
    visits = pd.read_csv('E:/IT/Yandex/Projects/datasets/marketing_visits.csv')
    orders = pd.read_csv('E:/IT/Yandex/Projects/datasets/marketing_orders.csv')
    ad_costs = pd.read_csv('E:/IT/Yandex/Projects/datasets/marketing_ad_costs.csv')

# %% [markdown]
# Проверим базы данных

# %%
# Определим функцию для знакомства с базой данных и проверки её на явные дубликаты
def database_check(db):
    print('Случайные 2 строки базы данных')
    display(db.sample(2, random_state=0))
    print('---')
    print('Общая информация о базе данных')
    db.info()
    print('---')
    print('Пропущенных значений в строках:')
    print(db.isna().sum())
    print('---')
    print('Явных дубликатов в базе данных:', db.duplicated().sum())

# %%
# Определим список баз данных для проверки
dtb = {
    "visits": visits,
    "orders": orders,
    "ad_costs": ad_costs,
    }
# Проведем знакомство с базами данных
for name, database in dtb.items():
    print('База данных', name)
    database_check(database)
# Out:
# База данных visits
# Случайные 2 строки базы данных
#         Unnamed: 0       User Id         Region   Device  Channel  \
# 230413      230413  537653514750             UK  Android  organic
# 55799        55799  508310853453  United States      Mac  organic
#
#               Session Start          Session End
# 230413  2019-06-18 11:00:35  2019-06-18 11:20:43
# 55799   2019-06-27 12:25:03  2019-06-27 13:11:26
# ---
# Общая информация о базе данных
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     309901 non-null  int64
#  1   User Id        309901 non-null  int64
#  2   Region         309901 non-null  object
#  3   Device         309901 non-null  object
#  4   Channel        309901 non-null  object
#  5   Session Start  309901 non-null  object
#  6   Session End    309901 non-null  object
# ...

# %% [markdown]
# Названия столбцов необходимо привести в змеиный регистр, даты и время перевести во временной формат.
# В остальном данные полные, без пропусков

# %%
# Переведем названия столбцов в нижний регистр и заменим пробелы нижним подчеркиванием
visits.columns= visits.columns.str.lower()
visits.columns = visits.columns.str.replace(' ', '_')
orders.columns= orders.columns.str.lower()
orders.columns = orders.columns.str.replace(' ', '_')
ad_costs.columns= ad_costs.columns.str.lower()

# Перводим формат столбцов во временной
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
visits['dt'] = visits['session_start'].dt.date
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
ad_costs['dt'] = pd.to_datetime(ad_costs['dt']).dt.date

# %% [markdown]
# Проверим, за какой период представлены данные и зададим дату анализа, указанную в задании

# %%
# Доступный интервал привлечения пользователей
min_analysis_date = visits['dt'].min()
max_analysis_date = visits['dt'].max()
# Момент анализа
observation_date = datetime(2019, 10, 27).date()  

print('Данные содержат записи с {} по {}'.format(min_analysis_date, max_analysis_date))
print('Момент анализа', observation_date)
# Out:
# Данные содержат записи с 2019-05-01 по 2019-10-31
# Момент анализа 2019-10-27

# %% [markdown]
# ### Выводы
#
# Исходные данные представлены в 3 таблицах. Таблицы не содержат пропущенных значений или неверных форматов записи данных. Для удобства обработки, все названия столбцов были приведены к змеиному регистру и столбцы, содержащие информацию о дате и времени переведены в соответствующий формат. Дальнейший анализ будет проводиться по данным, полученным с 1 мая по 27 октбяря 2019 года.

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии
# Зададим функции, с помощью которых в дальнейшем будем рассчитывать бизнес показатели

# %% [markdown]
# Функция расчета профилей пользователей

# %%
def get_profiles(sessions, orders, ad_costs):
    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )
    # для когортного анализа определяем дату первого посещения и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())
    # считаем количество уникальных пользователей с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
     # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')
     # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
     # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )
     # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    return profiles

# %% [markdown]
# Функция расчета коэффициента удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):
    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions
    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )
    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция расчета конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):
    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['session_start']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []
    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )
    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция расчета коэффициента окупаемости ROI и пожизненной ценности клиента LTV

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )
        roi = result.div(cac['cac'], axis=0)
        roi = roi[~roi['cohort_size'].isin([np.inf])]
        roi['cohort_size'] = cohort_sizes
        roi['cac'] = cac['cac']
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]
        return result, roi

    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )
    if 'cohort' in dimensions:
        dimensions = []
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Функции визуализации

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Выводы
#
# В проект были добавлены следующие функции для расчета бизнес показателей:
# 1. Профилей пользователей
# 2. Коэффициента удержания пользователей
# 3. Коэффициента конверсии пользователей
# 4. Коэффициента окупаемости ROI и пожизненной ценности клиента LTV
#
# Для визуализации показателей:
# 1. Сглаживание фрейма
# 2. Удержания
# 3. Конверсии
# 4. LTV и ROI

# %% [markdown]
# ## Исследовательский анализ данных
#
# Построим профили пользователей. Выясним:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# Рассчитаем показатели для анализа на основе ранее заданных функций

# %%
# профили пользователей
users = get_profiles(visits, orders, ad_costs)

# %% [markdown]
# Изучение распределения пользователей по странам

# %%
plt.figure(figsize=(10, 15))
# первый график 
ax1 = plt.subplot(2, 2, 1)   
users.groupby(['region']).agg({'user_id': 'nunique'}).plot.bar(grid=True, ax=ax1) 
plt.xlabel('Страна')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Количество пользователей')
plt.title('Все пользователи')
# второй график
ax2 = plt.subplot(2, 2, 2, sharey=ax1)
users.query('payer == True').groupby(['region']).agg({'user_id': 'nunique'}).plot.bar(color='green', grid=True, ax=ax2)   
plt.xlabel('Страна')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Количество пользователей')
plt.title('Платящие пользователи')
plt.show()

# %%
# Группировка всех пользователей по странам
users_all = users.groupby(['region']).agg({'user_id': 'nunique'}).reset_index()
# Группировка только платящих пользователей по странам
users_pay = users.query('payer == True').groupby(['region']).agg({'user_id': 'nunique'}).reset_index()

# Объединение таблиц
users_all = users_all.merge(users_pay, on='region')
# Расчет доли платящих пользователей
users_all['precent'] = (users_all['user_id_y'] / users_all['user_id_x'])

users_all.columns = ['region', 'all_users', 'pay_users', 'pay_percent']
users_all = users_all.style.format({'pay_percent':'{:.1%}'})

users_all
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e3cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e3cf_level0_col0" class="col_heading level0 col0" >region</th>
#       <th id="T_6e3cf_level0_col1" class="col_heading level0 col1" >all_users</th>
#       <th id="T_6e3cf_level0_col2" class="col_heading level0 col2" >pay_users</th>
#       <th id="T_6e3cf_level0_col3" class="col_heading level0 col3" >pay_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e3cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e3cf_row0_col0" class="data row0 col0" >France</td>
#       <td id="T_6e3cf_row0_col1" class="data row0 col1" >11058</td>
#       <td id="T_6e3cf_row0_col2" class="data row0 col2" >554</td>
#       <td id="T_6e3cf_row0_col3" class="data row0 col3" >5.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6e3cf_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# Подавляющее количество пользователей приложения привлекается из Соединенных Штатов Америки. В плане привлечения платящих пользователей, США так же заметно лидируют, привлекая в 2 раза больше платящих пользователей, чем европейцы. Европейские страны вносят примерно равный между собой вклад в количество новых пользователей, однако каждая из этих стран вносит не более 10% от вклада США.

# %% [markdown]
# Изучение распределения пользователей по устройству входа

# %%
plt.figure(figsize=(10, 15))
# первый график 
ax1 = plt.subplot(2, 2, 1)   
users.groupby(['device']).agg({'user_id': 'nunique'}).plot.bar(grid=True, ax=ax1) 
plt.xlabel('Устройство')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Количество пользователей')
plt.title('Все пользователи')
# второй график
ax2 = plt.subplot(2, 2, 2, sharey=ax1)
users.query('payer == True').groupby(['device']).agg({'user_id': 'nunique'}).plot.bar(color='green', grid=True, ax=ax2)   
plt.xlabel('Устройство')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Количество пользователей')
plt.title('Платящие пользователи')
plt.show()

# %%
# Группировка всех пользователей по устройству входа
users_all_device = users.groupby(['device']).agg({'user_id': 'nunique'}).reset_index()
# Группировка только платящих пользователей по устройству входа
users_pay_device = users.query('payer == True').groupby(['device']).agg({'user_id': 'nunique'}).reset_index()

# Объединение таблиц
users_all_device = users_all_device.merge(users_pay_device, on='device')
# Расчет доли платящих пользователей
users_all_device['precent'] = (users_all_device['user_id_y'] / users_all_device['user_id_x'])

users_all_device.columns = ['device', 'all_users', 'pay_users', 'pay_percent']
users_all_device = users_all_device.style.format({'pay_percent':'{:.1%}'})

users_all_device
# Out:
# <style type="text/css">
# </style>
# <table id="T_3280f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3280f_level0_col0" class="col_heading level0 col0" >device</th>
#       <th id="T_3280f_level0_col1" class="col_heading level0 col1" >all_users</th>
#       <th id="T_3280f_level0_col2" class="col_heading level0 col2" >pay_users</th>
#       <th id="T_3280f_level0_col3" class="col_heading level0 col3" >pay_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3280f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3280f_row0_col0" class="data row0 col0" >Android</td>
#       <td id="T_3280f_row0_col1" class="data row0 col1" >21841</td>
#       <td id="T_3280f_row0_col2" class="data row0 col2" >1782</td>
#       <td id="T_3280f_row0_col3" class="data row0 col3" >8.2%</td>
#     </tr>
#     <tr>
#       <th id="T_3280f_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# По устройствам входа картина более сбалансированная. Наибольшее количество пользователей приложения входит в него через iPhone, на втором месте - Android и на третьем - настольные компьютеры. По доле платящих пользователей все устройства в целом одинаковы

# %%
plt.figure(figsize=(10, 15))
# первый график 
ax1 = plt.subplot(2, 2, 1)   
users.groupby(['channel']).agg({'user_id': 'nunique'}).plot.bar(grid=True, ax=ax1) 
plt.xlabel('Канал привлечения')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Количество пользователей')
plt.title('Все пользователи')
# второй график
ax2 = plt.subplot(2, 2, 2, sharey=ax1)
users.query('payer == True').groupby(['channel']).agg({'user_id': 'nunique'}).plot.bar(color='green', grid=True, ax=ax2)   
plt.xlabel('Канал привлечения')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Количество пользователей')
plt.title('Платящие пользователи')
plt.show()

# %%
# Группировка всех пользователей по каналу привлечения
users_all_channel = users.groupby(['channel']).agg({'user_id': 'nunique'}).reset_index()
# Группировка только платящих пользователей по каналу привлечения
users_pay_channel = users.query('payer == True').groupby(['channel']).agg({'user_id': 'nunique'}).reset_index()

# Объединение таблиц
users_all_channel = users_all_channel.merge(users_pay_channel, on='channel')
# Расчет доли платящих пользователей
users_all_channel['precent'] = (users_all_channel['user_id_y'] / users_all_channel['user_id_x'])

users_all_channel.columns = ['channel', 'all_users', 'pay_users', 'pay_percent']
users_all_channel = users_all_channel.style.format({'pay_percent':'{:.1%}'})

users_all_channel
# Out:
# <style type="text/css">
# </style>
# <table id="T_b1bd8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1bd8_level0_col0" class="col_heading level0 col0" >channel</th>
#       <th id="T_b1bd8_level0_col1" class="col_heading level0 col1" >all_users</th>
#       <th id="T_b1bd8_level0_col2" class="col_heading level0 col2" >pay_users</th>
#       <th id="T_b1bd8_level0_col3" class="col_heading level0 col3" >pay_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1bd8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1bd8_row0_col0" class="data row0 col0" >AdNonSense</td>
#       <td id="T_b1bd8_row0_col1" class="data row0 col1" >3880</td>
#       <td id="T_b1bd8_row0_col2" class="data row0 col2" >440</td>
#       <td id="T_b1bd8_row0_col3" class="data row0 col3" >11.3%</td>
#     </tr>
#     <tr>
#       <th id="T_b1bd8_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
print('Всего привлечено {} пользователей, из них {} с помощью маркетинговых каналов'.format(list(users.groupby(['channel']).agg({'user_id': 'nunique'}).sum()), list(users.query('channel != "organic"').groupby(['channel']).agg({'user_id': 'nunique'}).sum())))
# Out:
# Всего привлечено [150008] пользователей, из них [93569] с помощью маркетинговых каналов

# %% [markdown]
# Из 12 каналов привлечения пользователей, наибольший вклад вносит органическое привлечение. С заметным отставанием от органического, но и заметным отрывом от остальных каналов привлечения, идут два канала - FaceBoom и TipTop. По привлечению платящих пользователей, FaceBoom и TipTop сохраняют свои позиции лидеров, в то время как доля органических пользователей резко снижается, хотя всё же занимает заметное 3 место.

# %% [markdown]
# Изучим привлечение пользователей по каналам привлечения во времени

# %%
users.pivot_table(
    index='dt',  # даты первых посещений
    columns='channel',  # источники переходов
    values='user_id',  # ID пользователей
    aggfunc='nunique'  # подсчёт уникальных значений
).plot(figsize=(15, 5), grid=True)
plt.xlabel('Время')
plt.ylabel('Количество пользователей')
plt.title('Все пользователи')
plt.show()

# %% [markdown]
# Изучим привлечение платящих пользователей по каналам привлечения во времени

# %%
users.query('payer == True').pivot_table(
    index='dt',  # даты первых посещений
    columns='channel',  # источники переходов
    values='user_id',  # ID пользователей
    aggfunc='nunique'  # подсчёт уникальных значений
).plot(figsize=(15, 5), grid=True)
plt.xlabel('Время')
plt.ylabel('Количество пользователей')
plt.title('Платящие пользователи')
plt.show()

# %% [markdown]
# Довольно интересно, что наибольший пик привлечения пользователей пришёлся на первый месяц, доступный для анализа, и этот пик связан с органическими пользователями. Возможно сработало сарафанное радио, или иные, не маркетинговые, способы информирования пользователей о приложении. С начала периода анализа, уверенные первые три места по количеству пользователей занимают упомянутые выше каналы привлечения пользователей, органический, FaceBoom и TipTop. При этом для остальных каналов привлечения в целом не наблюдается динамики, а наиболее активные каналы имеют тенденцию к росту количества привлекаемых пользователей. По платящим пользователям картина схожа, FaceBoom и TipTop привлекают всё больше пользователей, в то время как остальные каналы показывают стабильность.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Посетилели приложения приходят из четырех стран: США, Великобритании, Франции и Германии. Подавляющее количество пользователей, как общее, так и платящих, приходится на США. Остальные страны в целом равны в своем вкладе в количество привлекаемых пользователей.
#
# Клиенты приложения заходят в него с мобильных устройств и с персональных компьютеров. Заметно, что с мобильных устройств больше, что хорошо согласуется с общемировыми тенденциями к увеличению доли пользования мобильными устройствами. Больше всего пользователей заходят с iPhone.
#
# Всего в исследовании представлено 12 каналов рекламы приложения, один из которых органические пользователи, то есть те, кто нашёл приложения без прямого влияния маркетинговой компании. По общему количеству привлечений лидирует как раз органический канал, заметно опережая коммерческие. При этом, если изучить динамику привлечения, большая доля пользователей по этому каналу была привлечена в первый месяц анализа, а потом резко снизилась. На втором и третьем месте по привлечению идут каналы FaceBoom и TipTop, заметно опережая остальные. Если смотреть по платящим пользователям, то FaceBoom и TipTop здесь занимают первые места, в то время как органический канал переходит на третье место. Динамика привлечения платящих пользователей у FaceBoom и TipTop имеет в целом положительную тенденцию, в то время как большинство остальных каналов показывают значительно меньшие темпы прироста новых пользователей.

# %% [markdown]
# ## Маркетинг
#
# Выясним:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %%
print('Всего за исследуемый период на рекламу было потрачено {}$'.format(ad_costs['costs'].sum().astype(int)))
print('------')
print('Траты на каждый источник привлечения пользователей')
display(ad_costs.pivot_table(index='channel', values='costs', aggfunc='sum').sort_values(by='costs', ascending=False))

ad_costs.pivot_table(index='channel', values='costs', columns='dt', aggfunc='sum').T.plot(figsize=(20,7))
plt.xlabel('Время')
plt.ylabel('Траты на рекламу')
plt.title('Траты на рекламу по каналам привлечения пользователей')
plt.show()
# Out:
# Всего за исследуемый период на рекламу было потрачено 105497$
# ------
# Траты на каждый источник привлечения пользователей
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# По цифрам видно, что траты на рекламу в двух каналах - TipTop и FaceBoom, на порядок выше, чем на все остальные источники. При этом в начале периода изучения эти траты были соизмеримы с остальными каналаим, но за полгода выросли в несколько раз, в то время как траты на остальные каналы оставались более-менее стабильными.

# %% [markdown]
# Посмотрим, сколько в среднем стоило привлечение каждого покупателя

# %%
# print('Средние траты на привлечение одного пользователя по каналам привлечения')
# display(users.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean').sort_values(by='acquisition_cost', ascending=False))

users.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean').sort_values(by='acquisition_cost', ascending=False).plot.bar()
plt.xlabel('Канал привлечения')
plt.ylabel('Стоимость привлечения пользователей')
plt.xticks(rotation=45, ha='right')
plt.title('Средние траты на привлечение одного пользователя по каналам привлечения')
plt.show()

# %%
print('Средняя стоимость привлечения одного пользователя {}$'.format(round(users['acquisition_cost'].mean(), 2)))
print('Средняя стоимость привлечения одного платящего пользователя {}$'.format(round(users.query('payer == True')['acquisition_cost'].mean(), 2)))
# Out:
# Средняя стоимость привлечения одного пользователя 1.13$
# Средняя стоимость привлечения одного платящего пользователя 1.35$

# %% [markdown]
# Средняя стоимость привлечения пользователей около доллара. Опережая в 2 с лишним раза остальные каналы, на первом месте по стоимости привлчения находится канал TipTop. Средний такой пользователь обходится компании почти в 3 доллара. На втором и третьем месте находятся каналы FaceBom и AdNonSense, привлекающие пользоваталей за примерно 1 доллар. Остальные каналы привлекают пользователей меньше, чем за доллар.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Всего за исследуемый период на рекламу было потрачено 105 497 долларов, из которых примерно 83% было потрачено всего на два канала привлечения пользователей - TipTop (54 751 доллар) и FaceBoom (32 445 долларов). Траты на эти два канала привлечения пользователей возрастали на протяжении всего исследуемого периода, и в его конце стали примерно на порядок выше, чем на остальные источники.
#
# По средней стоимости привлечения каждого пользователя TipTop занимает непочетное первое место, привлекая пользователей за почти 3 доллара, в то время как через остальные каналы пользователи обходятся компании за доллар или меньше. Несмотря на огромный бюджет TipTop (52% от общего бюджета на маркетинг), этот канал привлекает всего 21% прользователей. Для сравнения на втором месте находится FaceBoom, и, используя 31% бюджета, привлекает 32% пользователей, в связи с чем стоимость привлечения каждого пользователя не такая большая, как у TipTop (около 1 доллара).

# %% [markdown]
# ## Окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируем общую окупаемость рекламы;
# - Проанализируем окупаемость рекламы с разбивкой по устройствам;
# - Проанализируем окупаемость рекламы с разбивкой по странам;
# - Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишем проблемы, которые обнаружили. Ответим на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости?
#
# При решении этого шага будем считать, что мы смотрим данные 1-го ноября 2019 года и что в организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# ### Общая окупаемость рекламы

# %%
# Зададим дату анализа 1 ноября 2019 года
observation_date = datetime(2019, 11, 1).date()

# %% [markdown]
# Нас не интересуют органические пользователи, так как затраты на рекламу для них составляют 0 долларов, при этом часть из них приносят доход компании, тем самым завышая реальные цифры окупаемости пользователей, привлеченных с помощью маркетинговых каналов

# %%
users = users.query('channel != "organic"')

# %%
# Расчет данных
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(users, orders, observation_date, 14, dimensions=[])
# Построение графиков
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14, window=14)

# %% [markdown]
# В среднем пользователи приносят приложению 0,9 доллара по прошествии 2 недель пользования. Этот показатель не зависит от времени, хотя затраты на рекламу на протяжении всего периода только растут. Поскольку средняя стоимость привлечения новых пользователей через рекламные каналы обходится компании в 1,2 доллара, окупаемость рекламы составляет только 80%, причем динамика окупаемости отрицательная.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам

# %%
# Расчет данных
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(users, orders, observation_date, 14, dimensions=['device'])
# Построение графиков
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14, window=14)

# %% [markdown]
# Лайфтайм у пользователей 4 устройств схожий, за 2 недели пользователи в среднем приносят всего 0,8-0,9 долларов компании. Динамика лайфтайма на 14 дней довольно стабильна.
#
# Вложения в рекламу за это время на всех платформах росло, особенно резко в первый месяц для iPhone и Mac. Наибольшие деньги были вложены в устройства компании Apple, меньше всего - в ПК.
#
# А зря. Возврат инвестиций положительный только для пользователей ПК, хоть и наступает в среднем только спустя 1,5 недели пользования приложением. Пользователи, заходящие в приложение с помощью Android, окупаются только на 90%, а iPhone/Mac в среднем только на 70%. При этом динамика окупаемости крайне тревожная: в первый месяц новые пользователи окупались на всех устройствах, кроме Mac, но потом началось резкое падение окупаемости и к концу изучаемого периода на 14 день после привлечения уже ни одна группа не окупается.

# %% [markdown]
# Поскольку основаная доля пользователей приложения из США, проанализируем отдельно информацию об устройствах входа в этой стране

# %%
usa_users = users.query('region == "United States"')
# Расчет данных
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(usa_users, orders, observation_date, 14, dimensions=['device'])
# Построение графиков
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14, window=14)

# %%
print('Устройства входа пользоваталей из США')
usa_users.pivot_table(index='device', values='user_id', aggfunc='count').reset_index().sort_values(by='user_id', ascending=False)
# Out:
# Устройства входа пользоваталей из США
#     device  user_id
# 3   iPhone    27548
# 1      Mac    15424
# 0  Android    12436
# 2       PC     6421

# %% [markdown]
# Основное число американцев пользуется iPhone, на втором и третьем месте, с отставанием почти вдвое, идут Mac и Android. Меньше всего американци пользуются ПК. Стоимость привлечения пользователей росла одинаково на всех 4 платформах, ровно как и окупаемость пользователей одинаково на всех платформах снижалась, следовательно, маркетинговая компания в США была направлена на все устройства, а не на какие-то отдельно. Чуть-чуть ближе к окупаемости находятся пользователи Android, но всё равно не окупаются.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %%
# Расчет данных
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(users, orders, observation_date, 14, dimensions=['region'])
# Построение графиков
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14, window=14)

# %% [markdown]
# Поскольку подавляющее количество пользователей приложения из США, то логично, что эти пользователи приносят больше денег в компанию. Вложения в рекламу для жителей Европы за первый месяц сильно снизились, в то время как в американский рынок было сделано на порядок больше инвестиций, чем до этого. При этом пользователи из Европы окупались уже на 4-5 день после регистрации, а пользователи из Америки в среднем не окупаются совсем. Динамика окупаемости в США  на 14 день резко снижается через месяц после начала исследуемого периода, в то время как в Европе она стабильна.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам

# %%
# Расчет данных
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(users, orders, observation_date, 14, dimensions=['channel'])
# Построение графиков
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14, window=14)

# %% [markdown]
# По прибыльности наилучшим образом выглядят каналы привлечения lambdaMediaAds и TipTop, привлекая в среднем 1,5 доллара за 2 недели. FaceBoom привлекает в среднем 0,8 доллара за лайфтайм пользователя. По динамике лайфтайма lambdaMediaAds и TipTop выделаются более высокими показателями, но в целом все каналы привлекают пользователей стабильно. Затраты на маркетинг за исследуемый период по каналам практически не менялись, кроме TipTop: здесь затраты выросли в несколько раз, повышаясь каждый месяц.
#
# Большинство каналов привлечения покупателей окупаются за 2-4 дня, при этом окупаются в 2-3 раза, что является хорошим показателем. Но три канала не окупаются вовсе, среди которых два - это TipTop и FaceBoom, куда вкладывается много денег и которые приводят значительную долю пользователей. По динамике окупаемости эти два канала также сильно отстают от остальных.

# %% [markdown]
# Изучим конверсию пользователей с разбивкой по разным категориям

# %%
print('Используемые устройства')
# получите сырые данные, таблицу конверсии и таблицу динамики конверсии
conversion_raw, conversion, conversion_history = get_conversion(visits, orders, observation_date, 14, dimensions = ['device'])

plot_conversion(conversion, conversion_history, 14) 

print('Страна')
# получите сырые данные, таблицу конверсии и таблицу динамики конверсии
conversion_raw, conversion, conversion_history = get_conversion(visits, orders, observation_date, 14, dimensions = ['region'])

plot_conversion(conversion, conversion_history, 14) 

print('Канал привлечения')
# получите сырые данные, таблицу конверсии и таблицу динамики конверсии
conversion_raw, conversion, conversion_history = get_conversion(visits, orders, observation_date, 14, dimensions = ['channel'])

plot_conversion(conversion, conversion_history, 14)
# Out:
# Используемые устройства
# Страна
# Канал привлечения

# %% [markdown]
# Пользователи всех устройств конвертируются примерно одинаково, разве что пользователи ПК чуть меньше. При этом конверсия пользователей на 14 день только росла на изучаемый период, одинаково для всех устройств.
#
# Лучше всего конвертируются пользователи из США, хуже - из Франции. Динамика конверсии не зависит от страны.
#
# Конверсия по каналам привлечения наиболее дифференцированная. Выделаются 3 наиболее хорошо конверсируемых канала: lambdaMediaAds, TipTop, RocketSuperAds, так же хорошо конверсируется WahooNetBanner, остальные - в 2-3 раза хуже. Динамика конверсии в целом стабильна и все лидеры сохраняются теми же.

# %% [markdown]
# Изучим удержание пользователей с разбивкой по разным категориям

# %%
print('Используемые устройства')
# смотрим удержание с разбивкой по устройствам
retention_raw, retention, retention_history = get_retention(
    users, visits, observation_date, 14, dimensions = ['device']
)
plot_retention(retention, retention_history, 14) 

print('Страна')
# смотрим удержание с разбивкой по странам
retention_raw, retention, retention_history = get_retention(
    users, visits, observation_date, 14, dimensions = ['region']
)
plot_retention(retention, retention_history, 14) 

print('Канал привлечения')
# смотрим удержание с разбивкой по каналу привлечения
retention_raw, retention, retention_history = get_retention(
    users, visits, observation_date, 14, dimensions = ['channel']
)
plot_retention(retention, retention_history, 14)
# Out:
# Используемые устройства
# Страна
# Канал привлечения

# %% [markdown]
# Удержание пользователей с разных устройств в целом совпадает с прогнозируемым и практически не зависит от типа устройства.
#
# Удержание пользователей из США заметно ниже, чем из Европы.
#
# Удержание пользователей, привлеченных по разным каналам, в целом одинаковое, кроме привлеченных с помощью канала FaceBoom. Практически никто из пользователей, привлеченных через FaceBoom, не пользуется приложением спустя 2 недели после первого использования.
#
# Удержание неплатящих пользователей вполне предсказуемо и не вызывает каких-либо вопросов. Неплатящие пользователи стабильно удерживаются плохо и через 2 недели после регистрации практически не используют приложение. Очень хорошо соотносятся графики удержания платящих и неплатящих пользователей с разбивкой по каналам привлечения. Пользователи, привлеченные с помощью каналов AdNonSense и FaceBoom, удерживаются так же, как неплатящие пользователи, то есть очень плохо. Но в случае AdNonSense - это не большие потери, так как таких пользователей привлекается крайне мало и затраты на рекламу низкие, а в случае FaceBoom - это очень большая проблема, т.к. на рекламу по этому каналу трятятся крупные деньги.

# %% [markdown]
# ## Выводы
#
# **Причины неэффективности привлечения пользователей**
#
# В целом, реклама не окупается. Хуже всего окупаются клиенты, пользующиеся устройствами Apple, находящиеся в США и привлеченные двумя наиболее затратными каналами привлечения.
#
# 83% инвестиций идут всего в 2 канала, работающих исключительно на американский рынок: TipTop и FaceBoom. Эти каналы привлекают около 52% пользователей, но показатели привлечения у них сильно разнятся:
# - TipTop принёс компании около 20000 новых пользователей и стоил 55 000 долларов, то есть каждый пользователь обошёлся компании почти в 3 доллара. Затраты на рекламу через этот канал росли очень высокими темпами на протяжении изучаемого периода. В среднем пользователи, пришедшие через этот канал, приносят компании 1,5 доллара. Динамика окупаемости отрицательная. Конверсия пользователей высокая, динамика удержания средняя
# - FaceBoom принёс компании около 30000 новых пользователей и стоил 32000 долларов, то есть каждый пользователь обошёлся компании примерно в 1 доллар. Затраты на рекламу через этот канал были стабильны на протяжении изучаемого периода. В среднем пользователи, пришедшие через этот канал, приносят компании 0,8 доллара. Динамика окупаемости отрицательная. Конверсия пользователей низкая, динамика удержания крайне низкая
#
# Таким образом, эти два канала привлекают непропорционально затратам меньше пользователей, которые плохо удерживаются, в следствии чего не окупаются.
#
# Кроме вышесказанных, выделяются ещё два канала: AdNonSense и lambdaMediaAds: AdNonSense показывает хорошие показатели по конверсии, но плохие по удержанию, lambdaMediaAds показывает хорошие показатели и конверсии и удержания.
#
# **Рекомендации для отдела маркетинга для повышения эффективности**
#
# Инвестиции в рынок США оправданы, так как подавляющая часть пользователей находятся в этой стране, и конверсия пользователей здесь выше, чем в Европе. Но необходимо пересмотреть подход к двум каналам привлечения: TipTop и FaceBoom.
# - TipTop привлекает качественных пользователей, которые хорошо конверсируются, но затраты на такую рекламу слишком высоки, чтобы окупаться. Нужно подумать над путем уменьшения или хотя бы стабилизации затрат по этому каналу. И возможно расширению на Европейский рынок
# - FaceBoom привлекает менее качественных пользователей, но в связи с меньшими затратами на привлечение, окупаемость почти достигается. Главная проблема с этим каналом - в низкой конверсии и крайне низкой динамике удержания, что может говорить о том, что пользователи, привлеченные по этому каналу, скорее всего не являются целевой аудиторией приложения. Можно рекомендовать отказаться от этого канала
#
# Помимо главных каналов, следует обратить внимание на следующие моменты:
# - Пересмотреть маркетинговую стратегию канала AdNonSense, почему пользователи при хорошей конверсии плохо удерживаются
# - Перераспределить вложения в канал lambdaMediaAds, так как это наиболее перспективный канал с хорошей конверсией, удержанием и окупаемостью, но пока с низким бюджетом
# - Вложиться в доработку приложения на iPhone, так как это основное устройство, которым пользуются клиенты в США
